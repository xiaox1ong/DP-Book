# %% [markdown]
# <a href="https://colab.research.google.com/github/xiaox1ong/DP-Book/blob/master/ChatGPT_70_Plugin_Advanced_Prompts_5_13_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This document is a compilation of included Advanced Prompts for all 70 Current ChatGPT Plugins based on their Description, Basic Prompt  and Use Case Interpretation. I hope this will be helpful for users who are looking for more information about the different plugins available.
#
# Please feel free to add your own suggestions and feedback to the document. I hope this will help us to create a comprehensive and useful resource for users of ChatGPT.
#
# Thank you for your collaboration!
#
# Here are some additional details about the document:
# - The document is organized by plugin.
# - Each plugin section includes a description of the plugin, a basic prompt, and a list of advanced prompts.
# - The advanced prompts are designed to help users get the most out of the plugins.
# - The document is still under development, so please feel free to add your own suggestions and feedback.
#
# 70 Current Plugins as of 5-13-2023
#
#
#
# 1. **KeyMate.AI Search**
#    - Description: Search the web using a custom search engine powered by AI.
#    - Basic Prompt: "Search the web for the latest research on renewable energy sources."
#    - Use Case Interpretation: Useful for users who need to perform web searches within their chat interface.
#    - Advanced Prompts:
#      1. "Find me the top 5 articles on the impact of AI in healthcare."
#      2. "Search for recent studies on the effects of climate change on marine life."
#      3. "Locate the latest news about the Mars Rover mission."
#
# 2. **Zapier**
#    - Description: Interact with over 5,000+ apps like Google Sheets, Gmail, HubSpot, Salesforce, and more.
#    - Basic Prompt: "Connect my Google Sheets to fetch data about my latest expenses."
#    - Use Case Interpretation: Ideal for users who want to automate tasks between different online apps.
#    - Advanced Prompts:
#      1. "Set up a Zapier workflow to save my Gmail attachments to Dropbox."
#      2. "Create a Zap to post my Instagram photos to Twitter."
#      3. "Automate a task to add new Salesforce leads to my Google Sheets."
#
# 3. **edX**
#    - Description: Find courses and content from leading universities to expand your knowledge at any level.
#    - Basic Prompt: "Find me a course on machine learning from a leading university."
#    - Use Case Interpretation: Great for lifelong learners looking to take courses from top universities.
#    - Advanced Prompts:
#      1. "Search for a beginner's course on Python programming on edX."
#      2. "Find me a course on digital marketing from a top-rated university."
#      3. "Locate a comprehensive course on data science."
#
# 4. **Hauling Buddies**
#    - Description: Locate dependable animal transporters using recommendations, reviews, and regulatory compliance search features.
#    - Basic Prompt: "Find a reliable animal transporter in Los Angeles."
#    - Use Case Interpretation: Perfect for pet owners who need to transport their animals safely.
#    - Advanced Prompts:
#      1. "Find a pet transporter in New York who can transport my dog to San Francisco."
#      2. "Search for a licensed and insured animal transporter in Miami."
#      3. "Locate a pet transporter with positive reviews in Chicago."
#
# 5. **Yay! Forms**
#    - Description: Create AI-Powered Forms, Surveys, Quizzes, or Questionnaires on Yay! Forms.
#    - Basic Prompt: "Create a survey to gather feedback on our latest product."
#    - Use Case Interpretation: Useful for users who need to create forms, surveys, or quizzes.
#    - Advanced Prompts:
#      1. "Design a quiz to test the knowledge of our employees on cybersecurity best practices."
#      2. "Create a form to collect RSVPs for our upcoming event."
#      3. "Build a survey to gauge customer satisfaction with our new service."
#
# 6. **Savvy Trader AI**
#    - Description: Provides real-time stock, crypto, and other investment data.
#    - Basic Prompt: "What's the latest price of Bitcoin?"
#    - Use Case Interpretation: Ideal for investors who need real-time data on stocks and cryptocurrencies.
#    - Advanced Prompts:
#      1. "Give me the latest price and volume data for Tesla stock."
#      2. "Show me the historical price data for Ethereum over the past year."
#      3. "Find the top-performing stocks in the tech sector today."
#
# 7. **Diagram It**
#    - Description: Create and edit diagrams directly in chat.
#    - Basic Prompt: "Create a flowchart diagram to illustrate the software development lifecycle."
#    - Use Case Interpretation: Perfect for users who need to create and edit diagrams within their chat interface.
#    - Advanced Prompts:
#      1. "Draw a Venn diagram showing the overlap between cats, mammals, and pets."
#      2. "Create a process flow diagram for a customer service call."
#      3. "Design an organizational chart for a company with three departments."
#
# 8. **ndricks Sports**
#    - Description: Get information about pro teams (NHL, NBA, NFL, MLB) teams by calling the ndricks Software Sports API.
#    - Basic Prompt: "Get the latest scores for the NBA."
#    - Use Case Interpretation: Great for sports fans who want information about their favorite pro teams.
#    - Advanced Prompts:
#      1. "Show me the current NFL standings."
#      2. "Find the top scorers in the NHL this season."
#      3. "Give me the schedule for the next MLB games."
#
# 9. **Ambition**
#    - Description: Search millions of jobs near you.
#    - Basic Prompt: "Search for data analyst jobs in New York City."
#    - Use Case Interpretation: Ideal for job seekers who want to search for jobs near them.
#    - Advanced Prompts:
#      1. "Find remote software developer jobs that require Python skills."
#      2. "Search for part-time graphic design jobs in Los Angeles."
#      3. "Locate entry-level marketing jobs in the tech industry."
#
# 10. **Crafty Clues**
#    - Description: Guess the words that the AI craftily clues for you. Add restrictions to make the game more interesting!
#    - Basic Prompt: "Start a game of Crafty Clues with the theme 'Animals'."
#    - Use Case Interpretation: Perfect for users who enjoy word games and puzzles.
#    - Advanced Prompts:
#      1. "Play a game of Crafty Clues with the theme 'Movies'."
#      2. "Start a game of Crafty Clues with the theme 'Historical Figures'."
#      3. "Begin a game of Crafty Clues with the theme 'Geography'."
#
# 11. **Speak**
#    - Description: Learn how to say anything in another language with Speak, your AI-powered language tutor.
#    - Basic Prompt: "How do you say 'Where is the library?' in French?"
#    - Use Case Interpretation: Useful for language learners who want to learn how to say phrases in different languages.
#    - Advanced Prompts:
#      1. "Translate 'I love learning new languages' into Spanish."
#      2. "How do you say 'Good morning, how are you?' in Italian?"
#      3. "Translate 'What time is it?' into German."
#
# 12. **Cloudflare Radar**
#    - Description: Get real-time insights into Internet traffic patterns and threats as seen by Cloudflare.
#    - Basic Prompt: "Get real-time insights into Internet traffic for my website."
#    - Use Case Interpretation: Ideal for users who need real-time insights into Internet traffic patterns and threats.
#    - Advanced Prompts:
#      1. "Show me the traffic patterns for my website over the past week."
#      2. "Identify any potential threats to my website in the last 24 hours."
#      3. "Provide a breakdown of the geographic locations of my website visitors."
#
# 13. **Shop**
#    - Description: Search for millions of products from the world's greatest brands.
#    - Basic Prompt: "Search for the latest iPhone model."
#    - Use Case Interpretation: Perfect for shoppers who want to search for products from top brands.
#    - Advanced Prompts:
#      1. "Find the best deals on Samsung Galaxy smartphones."
#      2. "Search for eco-friendly home cleaning products."
#      3. "Show me the top-rated laptops for gaming."
#
# 14. **Coupert**
#    - Description: Search for the internet's best coupons from thousands of online stores.
#    - Basic Prompt: "Find the best coupons for electronics on Amazon."
#    - Use Case Interpretation: Great for bargain hunters looking for the best online coupons.
#    - Advanced Prompts:
#      1. "Find discount codes for home decor items on Etsy."
#      2. "Search for the latest deals on fashion items at Zara."
#      3. "Show me the best coupons for groceries at Walmart."
#
# 15. **Wishbucket**
#    - Description: Unified product search across all Korean platforms and brands.
#    - Basic Prompt: "Search for BTS merchandise across all Korean platforms."
#    - Use Case Interpretation: Ideal for users interested in Korean products and brands.
#    - Advanced Prompts:
#      1. "Find the latest K-beauty skincare products across all Korean platforms."
#      2. "Search for BLACKPINK merchandise on Korean shopping sites."
#      3. "Show me the top-rated Korean snacks available for international shipping."
#
# 16. **Lexi Shopper**
#    - Description: Get product recommendations from your local Amazon store.
#    - Basic Prompt: "Get product recommendations for home appliances from my local Amazon store."
#    - Use Case Interpretation: Perfect for Amazon shoppers who want product recommendations.
#    - Advanced Prompts:
#      1. "Recommend the best-rated kitchen gadgets on Amazon."
#      2. "Find the top-selling books in the self-help category on Amazon."
#      3. "Show me the most wished for items in the electronics category on Amazon."
#
# 17. **Prompt Perfect**
#    - Description: Type 'perfect' to craft the perfect prompt, every time.
#    - Basic Prompt: "Craft a perfect prompt for a discussion about climate change."
#    - Use Case Interpretation: Useful for users who need help crafting the perfect chat prompt.
#    - Advanced Prompts:
#      1. "Create a compelling prompt for a debate on the pros and cons of remote work."
#      2. "Craft a thought-provoking prompt for a conversation about mental health awareness."
#      3. "Generate a stimulating prompt for a discussion on the future of artificial intelligence."
#
# 18. **CreatiCode Scratch**
#    - Description: Display Scratch programs as images and write 2D/3D programs using CreatiCode Scratch extensions.
#    - Basic Prompt: "Display a Scratch program that simulates a bouncing ball."
#    - Use Case Interpretation: Great for users who want to display Scratch programs as images and write 2D/3D programs.
#    - Advanced Prompts:
#      1. "Show a Scratch program that simulates the solar system."
#      2. "Create a 2D Scratch program that mimics the game of Pong."
#      3. "Display a 3D Scratch program that models a rotating cube."
#
# 19. **Klarna Shopping**
#    - Description: Search and compare prices from thousands of online shops.
#    - Basic Prompt: "Compare prices for a Nikon DSLR camera from different online shops."
#    - Use Case Interpretation: Ideal for shoppers who want to compare prices from thousands of online shops.
#    - Advanced Prompts:
#      1. "Find the best deals on Adidas running shoes across different online stores."
#      2. "Compare prices for the latest iPad model from various online retailers."
#      3. "Search for the cheapest options for a KitchenAid mixer from different online shops."
#
# 20. **Glowing**
#    - Description: Schedule and send daily SMS messages - reminders, inspiration, helpers and more.
#    - Basic Prompt: "Schedule an inspirational SMS message for tomorrow morning."
#    - Use Case Interpretation: Perfect for users who want to schedule and send daily SMS messages.
#    - Advanced Prompts:
#      1. "Schedule a reminder SMS for my doctor's appointment next Tuesday at 3 PM."
#      2. "Send an inspirational quote to my phone every morning at 7 AM."
#      3. "Schedule a daily SMS reminder to drink water every 2 hours during the day."
#
# 21. **Giftwrap**
#     - Description: Ask about gift ideas for any occasion and recipient. Get it wrapped and delivered, no address needed.
#     - Basic Prompt: "Give me gift ideas for my friend's baby shower."
#     - Use Case Interpretation: Great for users who need gift ideas and want them wrapped and delivered.
#     - Advanced Prompts:
#         - "I need a gift for my boss who loves golf. Can you suggest something under $50?"
#         - "Find a unique anniversary gift for my wife who loves art and music."
#         - "What's a good housewarming gift for a family moving into a new home?"
#
# 22. **KalendarAl**
#     - Description: KalendarAl sales agents generate revenue with potential customers from 200+ million companies globally.
#     - Basic Prompt: "Generate potential customers from tech companies in Silicon Valley."
#     - Use Case Interpretation: Ideal for sales agents who want to generate revenue with potential customers.
#     - Advanced Prompts:
#         - "Find potential customers in the healthcare sector in Boston."
#         - "Generate a list of potential clients from fintech companies in London."
#         - "Identify potential customers from e-commerce companies in India."
#
# 23. **Wolfram**
#     - Description: Access computation, math, curated knowledge & real-time data through Wolfram|Alpha and Wolfram Language.
#     - Basic Prompt: "Compute the integral of x^2 from 0 to 10."
#     - Use Case Interpretation: Perfect for users who need access to computation, math, curated knowledge, and real-time data.
#     - Advanced Prompts:
#         - "Solve the differential equation dy/dx = y^2."
#         - "Calculate the eigenvalues of the matrix [[1, 2], [3, 4]]."
#         - "Find the limit as x approaches 0 of sin(x)/x."
#
# 24. **Weather Report Data**
#     - Description: Current weather data for cities and airports using METAR aviation feeds.
#     - Basic Prompt: "Get the current weather data for Los Angeles airport."
#     - Use Case Interpretation: Great for users who want current weather data for cities and airports.
#     - Advanced Prompts:
#         - "What's the current temperature and humidity at JFK airport?"
#         - "Get the wind speed and direction for San Francisco airport."
#         - "What's the visibility at London Heathrow airport?"
#
# 25. **ChatWithPDF**
#     - Description: Plugin for asking questions, analyzing, and parsing through PDF documents by simply providing a PDF URL.
#     - Basic Prompt: "Analyze the third chapter of the PDF document at this URL."
#     - Use Case Interpretation: Ideal for users who need to ask questions, analyze, and parse through PDF documents.
#     - Advanced Prompts:
#         - "Extract all the images from the PDF at this URL."
#         - "Find all mentions of 'climate change' in the PDF at this URL."
#         - "Summarize the main points from the first chapter of the PDF at this URL."
#
# 26. **Vivian Health**
#     - Description: Take the first step to finding your next healthcare job.
#     - Basic Prompt: "Find healthcare job opportunities in New York."
#     - Use Case Interpretation: Perfect for healthcare professionals looking for their next job.
#     - Advanced Prompts:
#         - "Find nursing job opportunities in Chicago with a salary above $70,000."
#         - "Search for pediatrician job openings in Boston."
#         - "Find physical therapist job opportunities in San Francisco."
#
# 27. **Turo**
#     - Description: Search for the perfect Turo vehicle for your next trip.
#     - Basic Prompt: "Search for a luxury vehicle available for rent in San Francisco next weekend."
#     - Use Case Interpretation: Great for travelers who want to search for the perfect vehicle for their next trip.
#     - Advanced Prompts:
#         - "Find a convertible car available for rent in Miami for the first week of July."
#         - "Search for a minivan available for rent in Orlando during the Christmas holidays."
#         - "Find an electric car available for rent in Seattle for this weekend."
#
# 28. **Tabelog**
#     - Description: Allows you to find restaurants in Japan that have availability for reservations.
#     - Basic Prompt: "Find a sushi restaurant in Tokyo that has availability for reservations tonight."
#     - Use Case Interpretation: Ideal for users who want to find restaurants in Japan that have availability for reservations.
#     - Advanced Prompts:
#         - "Find a vegan-friendly restaurant in Kyoto that has availability for reservations tomorrow."
#         - "Search for a seafood restaurant in Osaka with a private dining option."
#         - "Find a traditional Japanese restaurant in Hiroshima that has a Michelin star."
#
# 29. **AlTickerChat**
#     - Description: Retrieve USA stock insights from SEC filings as well as Earnings Call Transcripts.
#     - Basic Prompt: "Retrieve the latest SEC filings for Google."
#     - Use Case Interpretation: Perfect for investors who want to retrieve USA stock insights from SEC filings and Earnings Call Transcripts.
#     - Advanced Prompts:
#         - "Get the latest earnings call transcript for Amazon."
#         - "Retrieve the latest SEC filings for Tesla."
#         - "Find the most recent earnings call transcript for Microsoft."
#
# 30. **Instacart**
#     - Description: Ask about recipes and discover the ingredients you need-then get it all delivered from local stores.
#     - Basic Prompt: "Find a recipe for chicken parmesan and add the ingredients to my shopping list."
#     - Use Case Interpretation: Great for users who want to ask about recipes and get the ingredients delivered from local stores.
#     - Advanced Prompts:
#         - "Find a vegan recipe for dinner and add the ingredients to my shopping list."
#         - "Search for a gluten-free dessert recipe and add the ingredients to my shopping list."
#         - "Find a low-carb breakfast recipe and add the ingredients to my shopping list."
#
# 31. **Comic Finder**
#     - Description: A plugin that finds a relevant comic given a description. Currently supports XKCD and SMBC comics.
#     - Basic Prompt: "Find an XKCD comic about machine learning."
#     - Use Case Interpretation: Ideal for comic fans who want to find relevant comics based on a description.
#     - Advanced Prompts:
#         - "Find an SMBC comic about quantum physics."
#         - "Search for an XKCD comic about programming."
#         - "Find a comic about space exploration."
# 32. **Manorlead**
#    - Description: Get a list of listings for rent or sale in cities across Canada and the US based on your search criteria.
#    - Basic Prompt: "Show me listings for 2-bedroom apartments for rent in Seattle."
#    - Use Case Interpretation: Perfect for individuals looking for housing options in specific cities across Canada and the US.
#    - Advanced Prompts:
#      1. "Find me listings for 3-bedroom houses for sale in Toronto with a budget of $500,000."
#      2. "Show me pet-friendly rental options in San Francisco under $3000 per month."
#      3. "Search for luxury condos for sale in Miami with ocean views."
#
# 33. **VoxScript**
#    - Description: Enables searching of YouTube transcripts, financial data sources, and Google Search results, and more!
#    - Basic Prompt: "Search the transcripts of TED Talks for mentions of artificial intelligence."
#    - Use Case Interpretation: Ideal for researchers or curious individuals who want to search through various data sources for specific information.
#    - Advanced Prompts:
#      1. "Find mentions of 'climate change' in recent political speeches on YouTube."
#      2. "Search for the latest financial reports of Tesla Inc. from reliable sources."
#      3. "Locate Google Search results for 'best practices in remote work'."
#
# 34. **Open Trivia**
#    - Description: Get trivia questions from various categories and difficulty levels.
#    - Basic Prompt: "Give me a trivia question from the category of Science."
#    - Use Case Interpretation: Great for trivia enthusiasts or individuals looking to challenge their knowledge in various fields.
#    - Advanced Prompts:
#      1. "Provide a set of 5 trivia questions in the category of 'World History'."
#      2. "Give me a hard-level trivia question about 'Space Exploration'."
#      3. "Generate a trivia question in the category of 'Literature'."
#
# 35. **DEV Community**
#    - Description: Plugin for recommending articles or users from DEV Community.
#    - Basic Prompt: "Recommend me an article about Python programming from the DEV Community."
#    - Use Case Interpretation: Ideal for developers or tech enthusiasts looking for relevant articles or users in the DEV Community.
#    - Advanced Prompts:
#      1. "Find me the top-rated articles about JavaScript frameworks on DEV Community."
#      2. "Recommend popular users on DEV Community who frequently write about cybersecurity."
#      3. "Search for recent articles about AI and Machine Learning on DEV Community."
#
# 36. **Word Sneak**
#    - Description: The AI has to sneak 3 secret words into your conversation. Guess the words to win the game!
#    - Basic Prompt: "Start a game where you sneak the words 'banana', 'astronaut', and 'monocle' into our conversation."
#    - Use Case Interpretation: Perfect for users who enjoy word games and want to challenge the AI in a fun conversation.
#    - Advanced Prompts:
#      1. "Let's play a game. Try to sneak the words 'elephant', 'telescope', and 'cupcake' into our chat."
#      2. "Start a game where you have to use the words 'rainbow', 'laptop', and 'pineapple' in our conversation."
#      3. "Let's play Word Sneak. Your words are 'butterfly', 'skyscraper', and 'chocolate'."
#
# 37. **Chess**
#    - Description: Unleash your inner chess master with this interactive chess experience! You can play against a novice or a grandmaster level AI.
#    - Basic Prompt: "Let's play a game of chess. I'll start: e4."
#    - Use Case Interpretation: Ideal for chess enthusiasts who want to play a game directly in the chat interface.
#    - Advanced Prompts:
#      1. "Start a game of chess with the AI set to grandmaster level."
#      2. "Let's play a game of chess. I'll start with the Sicilian Defense: c5."
#      3. "Play a game of chess. You start."
#
# 38. **WebPilot**
#    - Description: Browse & QA webpage/generate articles, from one or more URLs.
#    - Basic Prompt: "Generate an article summary from this URL."
#    - Use Case Interpretation: Great for users who need to browse and QA webpages or generate articles from URLs.
#    - Advanced Prompts:
#      1. "Generate a detailed summary of the article at this URL."
#      2. "Browse this webpage and extract the main points."
#      3. "Create a brief overview of the content on this webpage."
#
# 39. **Change**
#    - Description: Discover impactful nonprofits to support in your community and beyond.
#    - Basic Prompt: "Discover impactful environmental nonprofits to support in my local community."
#    - Use Case Interpretation: Ideal for users who want to discover and support impactful nonprofits in their community.
#    - Advanced Prompts:
#      1. "Find nonprofits focused on education in my local area."
#      2. "Discover international nonprofits working to combat climate change."
#      3. "Search for local nonprofits that support mental health initiatives."
#
# 40. **Noteable**
#    - Description: Create notebooks in Python, SQL, and Markdown to explore data, visualize, and share notebooks with everyone.
#    - Basic Prompt: "Create a Python notebook to analyze the data in this CSV file."
#    - Use Case Interpretation: Perfect for data scientists or analysts who want to create and share notebooks in Python, SQL, and Markdown.
#    - Advanced Prompts:
#      1. "Create a SQL notebook to analyze the data in this database."
#      2. "Generate a Python notebook to visualize the data in this Excel file."
#      3. "Build a Markdown notebook to document the findings from this data analysis."
#
# 41. **Likewise**
#    - Description: Your media and entertainment companion. Get TV, Movies, Books & Podcast Recommendations.
#    - Basic Prompt: "Recommend a thriller movie for me to watch tonight."
#    - Use Case Interpretation: Great for users looking for personalized recommendations for TV, movies, books, and podcasts.
#    - Advanced Prompts:
#      1. "Suggest a mystery novel for me to read."
#      2. "Recommend a comedy TV series for me to binge-watch."
#      3. "Find a popular podcast about technology for me to listen to."
#
# 42. **BlockAtlas**
#    - Description: Search the US Census! Find data sets, ask questions, and visualize.
#    - Basic Prompt: "Search the US Census data for the population of Los Angeles."
#    - Use Case Interpretation: Ideal for users who need to search US Census data and visualize the results.
#    - Advanced Prompts:
#      1. "Find the median income in San Francisco according to the US Census."
#      2. "Search the US Census data for the population growth rate in New York City."
#      3. "Locate data on the percentage of college graduates in Boston from the US Census."
#
# 43. **One Word Domains**
#    - Description: Check the availability of a domain and compare prices across different registrars.
#    - Basic Prompt: "Check the availability of the domain 'mynewbusiness.com'."
#    - Use Case Interpretation: Perfect for users who want to check the availability of a domain and compare prices across different registrars.
#    - Advanced Prompts:
#      1. "Find available .com domains that include the word 'tech'."
#      2. "Search for available domain names related to 'fitness' and compare their prices."
#      3. "Check if the domain 'innovativeAI.com' is available and provide the best price options."
#
# 44. **Ask YourPDF**
#    - Description: Unlock the power of your PDFs!, dive into your documents, find answers, and bring information to your fingertips.
#    - Basic Prompt: "Extract the third chapter from this PDF document."
#    - Use Case Interpretation: Great for users who need to dive into their PDF documents to find answers and bring information to their fingertips.
#    - Advanced Prompts:
#      1. "Analyze the first chapter of the PDF document at this URL and provide a summary."
#      2. "Extract all images from the PDF document at this URL."
#      3. "Search for all mentions of 'climate change' in the PDF document at this URL."
#
# 45. **Portfolio Pilot**
#    - Description: Your AI investing guide: portfolio assessment, recommendations, answers to all finance questions.
#    - Basic Prompt: "Assess my current investment portfolio and provide recommendations for diversification."
#    - Use Case Interpretation: Ideal for investors who want portfolio assessment, recommendations, and answers to finance questions.
#    - Advanced Prompts:
#      1. "Analyze my portfolio and suggest ways to increase my exposure to the tech sector."
#      2. "Evaluate my investment portfolio and provide a risk assessment."
#      3. "Review my portfolio and recommend any necessary adjustments to align with my retirement goals."
#
# 46. **Video Insights**
#    - Description: Interact with online video platforms like Youtube or Daily Motion.
#    - Basic Prompt: "Retrieve insights from the trending videos on YouTube."
#    - Use Case Interpretation: Perfect for users who want to interact with online video platforms like Youtube or Daily Motion.
#    - Advanced Prompts:
#      1. "Find the most viewed music video on YouTube in the last week."
#      2. "Search for the top trending cooking tutorials on YouTube."
#      3. "Retrieve insights from the most popular fitness videos on Daily Motion."
#
# 47. **Golden**
#    - Description: Get current factual data on companies from the Golden knowledge graph.
#    - Basic Prompt: "Get current factual data on Microsoft Corporation from the Golden knowledge graph."
#    - Use Case Interpretation: Great for users who want to get current factual data on companies from the Golden knowledge graph.
#    - Advanced Prompts:
#      1. "Provide the latest information on Google's acquisitions from the Golden knowledge graph."
#      2. "Retrieve data on the history and growth of Amazon from the Golden knowledge graph."
#      3. "Get information on the founders and executive team of Tesla from the Golden knowledge graph."
#
# 48. **Yabble**
#    - Description: Your ultimate AI research assistant; create surveys, specify audiences, collect data & analyze.
#    - Basic Prompt: "Create a survey to collect customer satisfaction data about our new product."
#    - Use Case Interpretation: Ideal for researchers who want to create surveys, specify audiences, collect data, and analyze results.
#    - Advanced Prompts:
#      1. "Design a survey to understand user experience with our mobile app."
#      2. "Create a survey targeting millennials to gather insights on their shopping habits."
#      3. "Analyze the data collected from our latest customer feedback survey."
#
# 49. **SEO.app**
#    - Description: Your personal SEO assistant for content marketing.
#    - Basic Prompt: "Analyze the SEO performance of my website 'www.mywebsite.com'."
#    - Use Case Interpretation: Perfect for content marketers who need a personal SEO assistant.
#    - Advanced Prompts:
#      1. "Provide an SEO audit of my e-commerce website."
#      2. "Give me a list of high-ranking keywords for the fitness industry."
#      3. "Analyze the backlink profile of my competitor's website."
#
# 50. **KAYAK**
#    - Description: Search flights, stays & rental cars or get recommendations where you can go on your budget.
#    - Basic Prompt: "Find the cheapest flights from New York to London in the first week of July."
#    - Use Case Interpretation: Great for travelers who want to search flights, stays, and rental cars or get recommendations based on their budget.
#    - Advanced Prompts:
#      1. "Find a hotel in Paris with a budget of $150 per night."
#      2. "Search for the best-rated car rental services in Los Angeles."
#      3. "Give me a list of popular tourist destinations I can visit with a budget of $2000."
#
# 51. **Biz Toc**
#    - Description: Search Biz Toc for business & finance news.
#    - Basic Prompt: "Search for the latest news on Tesla Inc. on Biz Toc."
#    - Use Case Interpretation: Ideal for users who want to search for business and finance news.
#    - Advanced Prompts:
#      1. "Find the latest news about the stock market crash."
#      2. "Search for recent articles on the impact of Brexit on the UK economy."
#      3. "Find the most recent updates on the cryptocurrency market."
#
# 52. **Tutory**
#    - Description: Access affordable, on-demand tutoring and education right at your fingertips.
#    - Basic Prompt: "Find an online math tutor for my 8th grade son."
#    - Use Case Interpretation: Perfect for students who need affordable, on-demand tutoring and education.
#    - Advanced Prompts:
#      1. "Search for a tutor who can help with high school chemistry homework."
#      2. "Find a Spanish tutor who can provide lessons twice a week."
#      3. "Locate a tutor who specializes in SAT preparation."
#
# 53. **Speechki**
#    - Description: The easiest way to convert texts to ready-to-use audio - download link, audio player page, or embed!
#    - Basic Prompt: "Convert this English text into French audio."
#    - Use Case Interpretation: Great for users who want to convert texts to ready-to-use audio.
#    - Advanced Prompts:
#      1. "Convert this Spanish text into English audio."
#      2. "Generate an audio file from this German text."
#      3. "Create an audio version of this Italian text."
#
# 54. **Bohita**
#    - Description: Create apparel with any image you can describe! Get it delivered right to your door.
#    - Basic Prompt: "Design a t-shirt with an image of a mountain at sunset."
#    - Use Case Interpretation: Ideal for users who want to create custom apparel with any image they can describe.
#    - Advanced Prompts:
#      1. "Design a hoodie with an image of a wolf under a full moon."
#      2. "Create a t-shirt with a picture of a city skyline at night."
#      3. "Design a tank top with an image of a tropical beach."
#
# 55. **Tasty Recipes**
#    - Description: Discover recipe ideas, meal plans and cooking tips from Tasty's millions of users!
#    - Basic Prompt: "Find a simple recipe for a vegetarian pasta dish."
#    - Use Case Interpretation: Perfect for users who want to discover recipe ideas, meal plans, and cooking tips.
#    - Advanced Prompts:
#      1. "Find a recipe for a gluten-free dessert."
#      2. "Search for a low-carb dinner recipe."
#      3. "Give me a list of quick and easy breakfast recipes."
#
# 56. **Zillow**
#    - Description: Your real estate assistant is here! Search listings, view property details, and get home with Zillow.
#    - Basic Prompt: "Show me listings for 2-bedroom apartments in San Francisco within a budget of $2000."
#    - Use Case Interpretation: Great for users who want to search real estate listings, view property details, and get home buying tips.
#    - Advanced Prompts:
#      1. "Find homes for sale in Austin within a budget of $300,000."
#      2. "Show me listings for 3-bedroom houses in Boston with at least 2 bathrooms."
#      3. "Search for rental properties in Seattle that allow pets."
#
# 57. **Polarr**
#    - Description: Search Polarr's massive pool of user-generated filters to make your photos and videos perfect.
#    - Basic Prompt: "Search for a filter to give my photos a vintage look."
#    - Use Case Interpretation: Ideal for users who want to search for user-generated filters to enhance their photos and videos.
#    - Advanced Prompts:
#      1. "Find a filter to give my photos a black and white effect."
#      2. "Search for a filter to enhance the colors in my sunset photos."
#      3. "Find a filter to give my photos a cinematic look."
#
# 58. **Keyplays Live Soccer**
#    - Description: Latest live soccer standings, results, commentary, TV stations, keyplays (with and without scores).
#    - Basic Prompt: "Provide the latest standings and results for the English Premier League."
#    - Use Case Interpretation: Perfect for soccer fans who want the latest live soccer standings, results, and commentary.
#    - Advanced Prompts:
#      1. "Give me the latest scores for the UEFA Champions League."
#      2. "Show me the current standings for the Spanish La Liga."
#      3. "Provide commentary for the latest match in the Italian Serie A."
#
# 59. **Keyplays Live Soccer**
#    - Description: Latest live soccer standings, results, commentary, TV stations, keyplays (with and without scores).
#    - Basic Prompt: "Provide the latest standings and results for the English Premier League."
#    - Use Case Interpretation: Great for soccer fans who want the latest live soccer standings, results, and commentary.
#    - Advanced Prompts:
#      1. "Give me a detailed commentary of the last match between Manchester United and Liverpool."
#      2. "Find the TV stations broadcasting the upcoming Champions League matches."
#      3. "Show me the keyplays from the last World Cup final."
#
# 60. **OpenTable**
#    - Description: Allows you to search for restaurants available for booking dining experiences.
#    - Basic Prompt: "Find available restaurants for a dinner booking in downtown Chicago this Saturday night."
#    - Use Case Interpretation: Ideal for users who want to search for restaurants available for booking dining experiences.
#    - Advanced Prompts:
#      1. "Find a romantic restaurant in San Francisco for a dinner date this Friday."
#      2. "Search for family-friendly restaurants in New York City with availability this weekend."
#      3. "Locate restaurants in Los Angeles that offer outdoor seating and are available for lunch tomorrow."
#
# 61. **GetYourGuide**
#    - Description: Find tours, excursions and other travel activities you can book on GetYourGuide.
#    - Basic Prompt: "Find the best-rated tours and excursions in Rome."
#    - Use Case Interpretation: Perfect for travelers who want to find tours, excursions, and other travel activities.
#    - Advanced Prompts:
#      1. "Find a guided tour of the Louvre Museum in Paris."
#      2. "Search for adventure activities in Queenstown, New Zealand."
#      3. "Locate the top-rated food tours in Tokyo."
#
# 62. **Wahi**
#    - Description: Hey Ontario, ask and get so in the know on the latest listings, property insights and more.
#    - Basic Prompt: "Show me the latest real estate listings in Toronto, Ontario."
#    - Use Case Interpretation: Great for users in Ontario who want to stay updated on the latest real estate listings and property insights.
#    - Advanced Prompts:
#      1. "Find 3-bedroom houses for sale in Ottawa within a budget of $500,000."
#      2. "Show me the latest condo listings in downtown Toronto."
#      3. "Search for rental properties in Hamilton that allow pets."
#
# 63. **Kraftful**
#    - Description: Your product development coach. Ask about best practices. Get top gurus' product thinking.
#    - Basic Prompt: "Give me best practices for product development in the tech industry."
#    - Use Case Interpretation: Ideal for product developers who want to ask about best practices and get insights from top gurus.
#    - Advanced Prompts:
#      1. "Provide tips for effective product management in a startup environment."
#      2. "Explain the role of user feedback in product development."
#      3. "Discuss the importance of cross-functional collaboration in product design."
#
# 64. **Shimmer: Nutrition**
#    - Description: Track meals & gain insights for a healthier lifestyle from 1m+ restaurants & grocery stores.
#    - Basic Prompt: "Track my meals for today and provide insights for a healthier lifestyle."
#    - Use Case Interpretation: Perfect for users who want to track meals and gain insights for a healthier lifestyle.
#    - Advanced Prompts:
#      1. "Analyze my food intake for the past week and suggest improvements for a balanced diet."
#      2. "Track my calorie intake for today and compare it with my daily recommended intake
#
#      3. "Provide a nutritional breakdown of the meals I've logged in today."
#
# 65. **Rentable Apartments**
#    - Description: Get apartment options in a city of your choice, scoped to your needs and budget.
#    - Basic Prompt: "Find 2-bedroom apartment options in Boston within a budget of $1800."
#    - Use Case Interpretation: Great for users who want to get apartment options in a city of their choice, scoped to their needs and budget.
#    - Advanced Prompts:
#      1. "Search for pet-friendly apartments in San Diego within a budget of $2000."
#      2. "Find studio apartments in downtown Seattle that are available for immediate move-in."
#      3. "Show me luxury apartments in Miami with a sea view."
#
# 66. **Scholar AI**
#    - Description: Unlock the power of scientific knowledge with fast, reliable, and peer-reviewed data at your fingertips.
#    - Basic Prompt: "Provide the latest peer-reviewed research on the effects of climate change."
#    - Use Case Interpretation: Ideal for users who want to unlock the power of scientific knowledge with fast, reliable, and peer-reviewed data.
#    - Advanced Prompts:
#      1. "Find recent studies on the impact of AI in medical diagnosis."
#      2. "Search for peer-reviewed articles on the benefits of renewable energy sources."
#      3. "Locate the latest research on the psychological effects of social media."
#
# 67. **Redfin**
#    - Description: Have questions about the housing market? Find the answers to help you win in today's market.
#    - Basic Prompt: "Give me an overview of the current housing market in Seattle."
#    - Use Case Interpretation: Perfect for users who have questions about the housing market and want to find the answers to help them win in today's market.
#    - Advanced Prompts:
#      1. "Provide a comparison of the housing market in San Francisco and Los Angeles."
#      2. "Show me the trend in house prices in New York City over the past year."
#      3. "Give me an analysis of the impact of COVID-19 on the US housing market."
#
# 68. **MixerBox OnePlayer**
#    - Description: Unlimited music, podcasts, and videos across various genres. Enjoy endless listening with our rich playlists!
#    - Basic Prompt: "Play the top trending songs in the pop genre."
#    - Use Case Interpretation: Ideal for music, podcast, and video enthusiasts who want unlimited access across various genres.
#    - Advanced Prompts:
#      1. "Play the latest episode of the 'StartUp' podcast."
#      2. "Find a playlist for a workout session."
#      3. "Play the top hits of the 80s."
#
# 69. **Expedia**
#    - Description: Bring your trip plans to life - get there, stay there, find things to see and do.
#    - Basic Prompt: "Plan a trip to Paris - find flights, hotels, and tourist attractions."
#    - Use Case Interpretation: Great for travelers who want to plan their trips, including transportation, accommodation, and activities.
#    - Advanced Prompts:
#      1. "Find the cheapest round-trip flights from New York to London in July."
#      2. "Search for 4-star hotels in Rome with availability in August."
#      3. "List the top-rated tourist attractions in Sydney."
#
# 70. **FiscalNote**
#    - Description: Fiscal Note enables access to select market-leading, real-time data sets for legal, political, and regulatory.
#    - Basic Prompt: "Provide real-time data for political trends in the U.S."
#    - Use Case Interpretation: Perfect for users who need access to real-time data sets for legal, political, and regulatory information.
#    - Advanced Prompts:
#      1. "Provide the latest updates on the upcoming Senate elections."
#      2. "Show me the recent voting record of Senator John Doe."
#      3. "Give me an overview of the current political climate in the U.S."
#
# Please note that these are potential use cases and the actual value to a given user will depend on their specific needs and how they choose to utilize each plugin.
